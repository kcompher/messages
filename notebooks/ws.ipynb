# %%
import pyEX

# %%
c = pyEX.topsWS(symbols='SIRI', on_data=print)

# %%
c.run()
# Out:
# {"symbol":"SIRI","sector":"mediaentertainment","securityType":"commonstock","bidPrice":5.7900,"bidSize":1000,"askPrice":5.8000,"askSize":1100,"lastUpdated":1540477069539,"lastSalePrice":5.7950,"lastSaleSize":100,"lastSaleTime":1540477059578,"volume":403051,"marketPercent":0.07577,"seq":3106}
# {"symbol":"SIRI","sector":"mediaentertainment","securityType":"commonstock","bidPrice":5.7900,"bidSize":1100,"askPrice":5.8000,"askSize":1100,"lastUpdated":1540477073337,"lastSalePrice":5.7950,"lastSaleSize":100,"lastSaleTime":1540477059578,"volume":403051,"marketPercent":0.07577,"seq":3107}
# {"symbol":"SIRI","sector":"mediaentertainment","securityType":"commonstock","bidPrice":5.7900,"bidSize":1100,"askPrice":5.8000,"askSize":1200,"lastUpdated":1540477085539,"lastSalePrice":5.7950,"lastSaleSize":100,"lastSaleTime":1540477059578,"volume":403051,"marketPercent":0.07570,"seq":3108}
# ...

# %%
c = pyEX.tradesWS(symbols=['AAPL', 'SNAP', 'MSFT'], on_data=print)

# %%
c.run()
# Out:
# WARNING:socketIO-client:ws-api.iextrading.com:443/socket.io [connection error] recv disconnected by SSL ([SSL: SSLV3_ALERT_BAD_RECORD_MAC] sslv3 alert bad record mac (_ssl.c:2217))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-951ccb5297f5> in <module>
# ----> 1 c.run()
#
# ~/code/messages/pyEX/pyEX/common.py in run(self)
#     142         if self.sendinit:
#     143             self.namespace.emit(*self.sendinit)
# --> 144         self.socketIO.wait()
#     145
#     146
#
# ~/conda/envs/messages/lib/python3.6/site-packages/socketIO_client_nexus/__init__.py in wait(self, seconds, **kw)
#     249             try:
#     250                 try:
# --> 251                     self._process_packets()
#     252                 except TimeoutError:
#     253                     pass
#
# ...
